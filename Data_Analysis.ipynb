# %%
from matplotlib import pyplot as plt
import pandas as pd

df = pd.read_csv('Data/combined_data.csv')
weights = df['weight'].unique()

# %%
print(weights)
# Out:
# [ 85.    86.6   87.95  89.2   90.65  91.8   92.9   94.4   95.5   96.55
#   97.9   99.1  100.3  101.5  103.1  104.5   85.1   86.7   88.35  89.4
#   90.6   91.95  93.35  94.5   95.    96.1   97.6   98.85 100.   101.6
#  103.    84.5   86.25  87.35  89.15  90.5   93.4   94.7   96.3   97.5
#  100.5  101.7  104.3  105.7 ]

# %%
# Step 3: Plot the histogram
plt.figure(figsize=(10, 6))
plt.hist(weights, bins=12, edgecolor='black')  # Adjust bins as needed
plt.title('Distribution of Weights')
plt.xlabel('Weight (kg)')
plt.ylabel('Quantity')
plt.grid(True)
plt.show()
